# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedElkhouly1992/Final-version-inshallah/blob/main/Before_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandas numpy matplotlib openpyxl

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cbbc382e-6a4c-42c5-88ff-c3e87b15fa3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbbc382e-6a4c-42c5-88ff-c3e87b15fa3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q HVAC_Degradation_Long_Horizon_Final_Suite.zip -d hvac_suite
# !find hvac_suite -maxdepth 2 -type f
# Out:
# hvac_suite/hvac_long_horizon_final_suite/requirements.txt
# hvac_suite/hvac_long_horizon_final_suite/THESIS_DEFENCE_METHODOLOGY.md
# hvac_suite/hvac_long_horizon_final_suite/streamlit_app.py
# hvac_suite/hvac_long_horizon_final_suite/hvac_degradation_long_horizon_suite.py
# hvac_suite/hvac_long_horizon_final_suite/COLAB_STEP_BY_STEP_CELLS.txt
# hvac_suite/hvac_long_horizon_final_suite/example_report_output.zip
# hvac_suite/hvac_long_horizon_final_suite/README_STEP_BY_STEP.md
# hvac_suite/hvac_long_horizon_final_suite/demo_5yr_hvac_degradation_dataset.csv
# hvac_suite/hvac_long_horizon_final_suite/make_demo_5yr_dataset.py

# %%
# !python hvac_suite/hvac_long_horizon_final_suite/hvac_degradation_long_horizon_suite.py \
  --input_file three_axis_ml_dataset.csv \
  --output_dir hvac_long_horizon_raw_training_results \
  --mode raw \
  --model_family catboost \
  --target_cols auto \
  --date_col auto \
  --horizons 20 30 \
  --make_zip
# Out:
# ZIP created: hvac_long_horizon_raw_training_results.zip
# Done. Results saved to: hvac_long_horizon_raw_training_results

# %%
# !pip install -q pandas numpy matplotlib scikit-learn joblib openpyxl streamlit catboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 65.5 MB/s eta 0:00:00

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50972013-915f-48eb-b728-99c4049e7b8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50972013-915f-48eb-b728-99c4049e7b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q HVAC_PhD_Final_Deployed_Framework.zip -d hvac_final
# !find hvac_final -maxdepth 2 -type f
# Out:
# hvac_final/HVAC_PhD_Final_Deployed_Framework/requirements.txt
# hvac_final/HVAC_PhD_Final_Deployed_Framework/streamlit_app.py
# hvac_final/HVAC_PhD_Final_Deployed_Framework/DEFENCE_WORDING_FINAL.md
# hvac_final/HVAC_PhD_Final_Deployed_Framework/COLAB_STEP_BY_STEP_FINAL.txt
# hvac_final/HVAC_PhD_Final_Deployed_Framework/README_FINAL_PHD_FRAMEWORK.md
# hvac_final/HVAC_PhD_Final_Deployed_Framework/demo_5yr_hvac_degradation_dataset.csv
# hvac_final/HVAC_PhD_Final_Deployed_Framework/make_demo_5yr_dataset.py
# hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py

# %%
# !python hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py \
  --mode train_project \
  --input_file three_axis_ml_dataset.csv \
  --output_dir phd_final_20_30yr_results \
  --model_family auto \
  --building_area_m2 17984.4 \
  --degradation_scenario moderate \
  --horizons 20 30 \
  --make_zip
# Out:
# /content/hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py:463: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x[mask].astype(float), y[mask].astype(float), 1)[0]
# /content/hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py:463: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x[mask].astype(float), y[mask].astype(float), 1)[0]
# /content/hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py:463: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x[mask].astype(float), y[mask].astype(float), 1)[0]
# /content/hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py:463: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x[mask].astype(float), y[mask].astype(float), 1)[0]
# /content/hvac_final/HVAC_PhD_Final_Deployed_Framework/hvac_phd_final_framework.py:463: RankWarning: Polyfit may be poorly conditioned
# ...

# %%
import pandas as pd

metrics = pd.read_csv("phd_final_20_30yr_results/chronological_validation_metrics.csv")
summary = pd.read_csv("phd_final_20_30yr_results/kpi_change_summary_20_30yr.csv")

display(metrics)
display(summary)
# Out:
#          RMSE        MAE        R2   MeanActual  NRMSE_pct  NMAE_pct  \
# 0   49.321966  35.539461  0.999773  5286.676448   0.932948  0.672246
# 1   64.933008  46.129439  0.999753  7272.581229   0.892847  0.634293
# 2   26.436574  19.049151  0.999773  2833.658576   0.932948  0.672246
# 3   34.804092  24.725379  0.999753  3898.103538   0.892847  0.634293
# 4    2.055082   1.480811  0.999773   220.278185   0.932948  0.672246
# 5    2.705542   1.922060  0.999753   303.024218   0.892847  0.634293
# 6    0.006891   0.005123  0.999823     3.341772   0.206210  0.153307
# 7    0.006877   0.005148  0.999802     3.237603   0.212413  0.159001
# 8    0.004197   0.003153  0.999707     0.622700   0.673981  0.506344
# 9    0.004356   0.003249  0.999709     0.629577   0.691842  0.516111
# 10   0.014797   0.010460  0.998697     0.365628   4.046937  2.860812
# 11   0.014525   0.010344  0.999050     0.523133   2.776501  1.977336
#
# ...

# %%
# !npm install -g localtunnel > /dev/null

# %%
# !streamlit run hvac_final/HVAC_PhD_Final_Deployed_Framework/streamlit_app.py --server.port 8501 &>/content/streamlit.log &

# %%
# !lt --port 8501
# Out:
# your url is: https://salty-bats-pump.loca.lt
# ^C

# %%
# !pkill -f streamlit || true
# !pkill -f localtunnel || true
# !pkill -f lt || true
# Out:
# ^C
# ^C
# ^C

# %%
# !mkdir -p ~/.streamlit

# %%
# %%writefile ~/.streamlit/config.toml
# [server]
# headless = true
# address = "0.0.0.0"
# port = 8501
# enableCORS = false
# enableXsrfProtection = false
# fileWatcherType = "none"
#
# [browser]
# gatherUsageStats = false
#
# [client]
# toolbarMode = "minimal"
# Out:
# Writing /root/.streamlit/config.toml

# %%
# !streamlit run hvac_final/HVAC_PhD_Final_Deployed_Framework/streamlit_app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  --server.enableCORS false \
  --server.enableXsrfProtection false \
  &>/content/streamlit.log &

# %%
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦⠧your url is: https://young-waves-shine.loca.lt
# ^C

# %%
# !pkill -f streamlit || true
# !pkill -f cloudflared || true
# Out:
# ^C
# ^C

# %%
# !streamlit run hvac_final/HVAC_PhD_Final_Deployed_Framework/streamlit_app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  --server.enableCORS false \
  --server.enableXsrfProtection false \
  &>/content/streamlit.log &

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared

# %%
# !./cloudflared tunnel --url http://localhost:8501 --no-autoupdate
# Out:
# 2026-05-14T14:33:15Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-05-14T14:33:15Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-05-14T14:33:19Z INF +--------------------------------------------------------------------------------------------+
# 2026-05-14T14:33:19Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...
